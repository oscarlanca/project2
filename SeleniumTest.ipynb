# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 from bs4 import BeatifulSoup
#
# ImportError: cannot import name 'BeatifulSoup' from 'bs4' (/Users/oscarlandivar/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py)

# %%
ruta_inegi2 = 'https://www.inegi.org.mx/app/tabulados/interactivos/?pxq=9171df60-8e9e-4417-932e-9b80593216ee'
driver = webdriver.Chrome()

# %%
driver.get(ruta_inegi2)

# %%
sopa = BeautifulSoup(driver.page_source)

# %%
sopa
# Out:
# <html lang="es"><head>
# <!-- Google Tag Manager -->
# ...

# %%
element = driver.find_element(By.CLASS_NAME, "zpop8FeV7OkeeMKGX-soi table table-bordered table-condensed table-responsive table-striped")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 element = driver.find_element(By.CLASS_NAME, "zpop8FeV7OkeeMKGX-soi table table-bordered table-condensed table-responsive table-striped")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %% [markdown]
# No se logró porque tenia un tema con cambiar variables de javascript a python.
# Lo seguiré intentando
